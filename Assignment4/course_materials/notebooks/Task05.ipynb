# %% [markdown]
# **Task 05: Reading and writing ontologies**

# %%
# !pip install rdflib 
github_storage = "https://raw.githubusercontent.com/daniel-dona/Curso2018-2019/master/Assignment3/"
# Out:
# Collecting rdflib
#   Downloading https://files.pythonhosted.org/packages/d0/6b/6454aa1db753c0f8bc265a5bd5c10b5721a4bb24160fb4faf758cf6be8a1/rdflib-5.0.0-py3-none-any.whl (231kB)
#      |████████████████████████████████| 235kB 5.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rdflib) (1.15.0)
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 5.8MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib) (2.4.7)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.0 rdflib-5.0.0

# %% [markdown]
# Leemos el fichero RDF de la forma que lo hemos venido haciendo

# %%
from rdflib import Graph, Namespace, Literal
g = Graph()
g.parse(github_storage+"/resources/example4.rdf", format="xml")
# Out:
# <Graph identifier=N9ffc39e28fed48d4943399a65cacf66d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Podemos comprobar las ternas que componen el documento de la misma forma.

# %%
for s, p, o in g:
  print(s,p,o)
# Out:
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.sowhere.com#http://xmlns.com/foaf/0.1/knows http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.sowhere.com#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.sowhere.com#JohnSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.sowhere.com#JaneSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/FN Jane Smith
# http://www.sowhere.com#JohnSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://www.sowhere.com#JaneSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://www.sowhere.com#JaneSmith http://www.sowhere.com#http://xmlns.com/foaf/0.1/email jSmith@somewhere.com
# http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.sowhere.com#http://xmlns.com/foaf/0.1/email http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.sowhere.com#http://xmlns.com/foaf/0.1/email http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.sowhere.com#JohnSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://www.sowhere.com#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.sowhere.com#Person
# http://www.sowhere.com#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.sowhere.com#Person
# http://www.sowhere.com#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.sowhere.com#JaneSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.sowhere.com#Person
# http://www.sowhere.com#JaneSmith http://www.sowhere.com#http://www.w3.org/2001/vcard-rdf/3.0/Given Jane

# %% [markdown]
# También podemos emplear otras herramientas como OntoSPY para visualizar una ontología

# %%
# !pip install ontospy
# Out:
# Requirement already satisfied: ontospy in /usr/local/lib/python3.6/dist-packages (1.9.8.3)
# Requirement already satisfied: rdflib-jsonld in /usr/local/lib/python3.6/dist-packages (from ontospy) (0.5.0)
# Requirement already satisfied: pyfiglet in /usr/local/lib/python3.6/dist-packages (from ontospy) (0.8.post1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from ontospy) (2.4.7)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from ontospy) (1.0.1)
# Requirement already satisfied: keepalive in /usr/local/lib/python3.6/dist-packages (from ontospy) (0.5)
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.6/dist-packages (from ontospy) (1.8.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from ontospy) (0.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from ontospy) (2.23.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.6/dist-packages (from ontospy) (5.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ontospy) (7.1.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from html5lib->ontospy) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from html5lib->ontospy) (0.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->ontospy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->ontospy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->ontospy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->ontospy) (1.24.3)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from rdflib->ontospy) (0.6.0)

# %%
from ontospy import Ontospy
data = '''

<?xml version="1.0"?>


<!DOCTYPE rdf:RDF [
    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
    <!ENTITY example4 "http://www.sowhere.com#" >
    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
]>


<rdf:RDF xmlns="http://www.sowhere.com#"
     xml:base="http://www.sowhere.com"
     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Object Properties
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->

    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Data properties
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->

    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->

    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdf:Property>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->

    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->

    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Classes
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->

    <rdfs:Class rdf:about="#Person"/>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->

    <rdfs:Class rdf:about="#Researcher">
        <rdfs:subClassOf rdf:resource="#Person"/>
    </rdfs:Class>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Individuals
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->

    <Person rdf:about="#JaneSmith">
        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
        <foaf:email rdf:datatype="&xsd;string"
            >jSmith@somewhere.com</foaf:email>
    </Person>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->

    <Person rdf:about="#JohnSmith">
        <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
        <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
    </Person>
</rdf:RDF>



<!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->



'''

model = Ontospy(data, verbose=True)
print(model.all_classes)
print(model.all_properties)
# Out:
# Reading: <
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
# >
# .. trying rdf serialization: <xml>
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# .. trying rdf serialization: <n3>
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# .. trying rdf serialization: <nt>
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# .. trying rdf serialization: <json-ld>
# Detected JSONLD - loading data into rdflib.ConjunctiveGraph()
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# .. trying rdf serialization: <turtle>
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# .. trying rdf serialization: <rdfa>
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
#  does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:file:///content/
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema does not look like a valid URI, trying to serialize this will break.
# ..... failed
# ----------
# Fatal error parsing graph <
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
# >
# (using RDF serializations: ['xml', 'n3', 'nt', 'json-ld', 'turtle', 'rdfa'])
# ----------
# TIP: You can try one of the following RDF validation services
# <http://mowl-power.cs.man.ac.uk:8080/validator/validate>
# <http://www.ivan-herman.net/Misc/2008/owlrl/>
# Sorry - no valid RDF was found
# ----------
# RDF sources failed to load: 1.
# ----------
# ->
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
# Scanning entities...
# ----------
# Ontologies.........: 0
# Classes............: 0
# Properties.........: 0
# ..annotation.......: 0
# ..datatype.........: 0
# ..object...........: 0
# Concepts (SKOS)....: 0
# Shapes (SHACL).....: 0
# ----------
# []
# []
