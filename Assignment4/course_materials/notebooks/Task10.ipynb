# %%
# !pip install rdflib owlrl
github_storage = "https://raw.githubusercontent.com/daniel-dona/Curso2018-2019/master/Assignment3/"

# %%
from rdflib import Graph, Namespace, Literal, URIRef
from owlrl import RDFSClosure, AxiomaticTriples
g1 = Graph()

g1.parse(github_storage+"resources/data05.rdf", format="xml")
# Out:
# <Graph identifier=Nb670ea0b7f1e496eba543b8c440b6638 (<class 'rdflib.graph.Graph'>)>

# %%
for t in g1:
  print(t)

rdfs = RDFSClosure.RDFS_Semantics(g1, False, False, False)

rdfs.add_axioms()

print(rdfs)

print("----")

for t in g1:
  print(t)
# Out:
# (rdflib.term.URIRef('http://data.five.org#PeterSmith'), rdflib.term.URIRef('http://www.w3.org/2001/vcard-rdf/3.0#Family'), rdflib.term.Literal('Smith', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://data.five.org#PeterSmith'), rdflib.term.URIRef('http://www.w3.org/2001/vcard-rdf/3.0#FN'), rdflib.term.Literal('Peter Smith', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://data.five.org#Jack'), rdflib.term.URIRef('http://www.w3.org/2001/vcard-rdf/3.0#Given'), rdflib.term.Literal('Jack', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://data.five.org#Harry'), rdflib.term.URIRef('http://data.five.org#sibling'), rdflib.term.URIRef('http://data.five.org#Thomas'))
# ...
